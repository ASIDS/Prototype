# %% [markdown]
# ## Initilize Feature Shape
# ##### Empty Sets
# ##### DATASET = 500 Data of 40 x 173 features
# ##### Target = 500

# %%
import numpy as np
import librosa
totaldata =20000
##featureShape_x = z.shape[0]
##featureShape_y = z.shape[1]
featureShape_x = 98
featureShape_y = 40
dataset = np.ndarray(shape=(totaldata,featureShape_x,featureShape_y))
target =   np.ndarray(shape=(totaldata))

print ("Total data",totaldata)
print ("Features Shape X",featureShape_x)
print ("Features Shape Y",featureShape_y)
print ("Initial Dataset Empty Array Shape",dataset.shape)
print ("Initial Target Empty Array Shape",target.shape)
# Out:
# Total data 20000
# Features Shape X 98
# Features Shape Y 40
# Initial Dataset Empty Array Shape (20000, 98, 40)
# Initial Target Empty Array Shape (20000,)

# %% [markdown]
# # SELECT FILE TO EXTRACT ALL WAV FILE

# %%
import wave, sys, pyaudio
import contextlib
from pydub import AudioSegment
import os
import scipy.io.wavfile as wav
import speechpy
import contextlib
import wave
import numpy as np

import numpy 
from pydub import AudioSegment
import os
import librosa
path = 'C:/Users/Another/CNN/RAW/Validated/Logging Road'
path = 'C:/Users/Another/CNN/RAW/Validated/Combine Test'
path = 'C:/Users/Another/CNN/RAW/Validated/Combine Train'
files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.WAV' in file:
            files.append(os.path.join(r, file))
            
            
totalDataWillBe = 0           
           
for f in files:
    if(f.__contains__("_BU")==0):
        if(1):
            #print(f)
            cutSeconds = 5
            slideSeconds = 0.25
            shift = int(cutSeconds/slideSeconds) - 1
            #print("Audio Shift seconds",slideSeconds)
            #print("Audio Shifts Segments",shift)

            if(shift == 0):
                shift = 1
            i =0
            para_fl = 0.1
            para_ovlp = 0.8


            totalFiles = 0
            for f in files:
                if(f.__contains__("_BU")==0):
                    if(1):
                        for z in range(shift): 
                            fname = f
                            with contextlib.closing(wave.open(fname,'r')) as faa:
                                frames = faa.getnframes()
                                rate = faa.getframerate()
                                duration = frames / float(rate)
                            segs =int(duration/cutSeconds)            
                            totalDataWillBe = totalDataWillBe + segs
                            
                            duration

# %%
totalDataWillBe
# Out:
# 5437800

# %%
import wave, sys, pyaudio
import contextlib
from pydub import AudioSegment
import os
import scipy.io.wavfile as wav
import speechpy
import contextlib
import wave
import numpy as np
cutSeconds = 5
slideSeconds = 0.25
shift = int(cutSeconds/slideSeconds) - 1
print("Audio Shift seconds",slideSeconds)
print("Audio Shifts Segments",shift)

if(shift == 0):
    shift = 1
i =0
para_fl = 0.1
para_ovlp = 0.8


totalFiles = 0
for f in files:
    if(f.__contains__("_BU")==0):
        if(1):
            for z in range(shift): 
                fname = f
                with contextlib.closing(wave.open(fname,'r')) as faa:
                    frames = faa.getnframes()
                    rate = faa.getframerate()
                    duration = frames / float(rate)
                print("Reading File : ",fname,"With Target Label",1)
                print('SR',rate)
                print('duration',duration)
                segs =int(duration/cutSeconds)
                print('Segments',segs)    
                y = AudioSegment.from_wav(f)
                ShiftAudio = y[(slideSeconds*1000)*z:(cutSeconds*1000)*(segs)]
                segs = segs-1
                for sss in range(segs): 
                    newAudio = ShiftAudio[(cutSeconds*1000)*sss:(cutSeconds*1000)*(sss+1)]


                    newname = '/ZOOM'+f.split("\ZOOM")[1].split(".WAV")[0] + '_Shift' + str(z*int(slideSeconds*1000)) + 'ms_segments_'+ str(i) + '.WAV'
                    print('Extract Segment - ',newname)
                    ##COMMENT OUT SAVE FILE TO TEST RUN 
                    newAudio.export("TempDATA.WAV", format="wav")


                    fs, signal = wav.read("TempDATA.WAV")
                    print(f)
                    print(fs,"kHz")
                    print("Channels",signal.shape)
                    if(np.array_equal(signal.shape, [220500, ])):
                        print("1 Channel")
                    else:
                        signal = signal[0:44100*5,0]
                        print("2 Channels")

                    signal_preemphasized = speechpy.processing.preemphasis(signal, cof=0.98)
                    logenergy = speechpy.feature.lmfe(signal, sampling_frequency=fs, frame_length=para_fl, frame_stride=para_fl*0.5,
                    num_filters=40, fft_length=512, low_frequency=0, high_frequency=None)
                    
                    logenergy

                    dataset[i] = logenergy

                    if(f.__contains__("Ambience")):
                        target[i] = 0

                    elif(f.__contains__("Machete")):
                        target[i] = 1
                    elif(f.__contains__("Hatchet")):
                        target[i] = 1  
                    elif(f.__contains__("Chainsaw")):
                        target[i] = 2
                    else:
                        target[i] = 3

                    print("Data ",i)
                    print(f.split('CNN/')[1].split('\\')[0])
                    i += 1
# Out:
# Audio Shift seconds 0.25
# Audio Shifts Segments 19
# Reading File :  C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV With Target Label 1
# SR 44100
# duration 182.50448979591837
# Segments 36
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_0.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  0
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_1.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  1
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_2.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  2
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_3.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  3
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_4.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  4
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_5.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  5
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_6.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  6
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_7.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  7
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_8.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  8
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_9.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  9
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_10.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  10
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_11.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  11
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_12.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  12
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_13.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  13
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_14.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  14
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_15.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  15
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_16.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  16
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_17.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  17
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_18.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  18
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_19.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  19
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_20.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  20
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_21.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  21
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_22.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  22
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_23.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  23
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_24.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  24
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_25.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  25
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_26.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  26
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_27.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  27
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_28.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  28
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_29.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  29
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_30.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  30
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_31.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  31
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_32.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  32
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_33.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  33
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift0ms_segments_34.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  34
# RAW/Validated/Combine Test
# Reading File :  C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV With Target Label 1
# SR 44100
# duration 182.50448979591837
# Segments 36
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_35.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  35
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_36.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  36
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_37.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  37
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_38.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  38
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_39.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  39
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_40.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  40
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_41.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  41
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_42.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  42
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_43.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  43
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_44.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  44
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_45.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  45
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_46.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  46
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_47.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  47
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_48.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  48
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_49.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  49
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_50.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  50
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_51.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  51
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_52.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  52
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_53.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  53
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_54.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  54
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_55.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  55
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_56.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  56
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_57.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  57
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_58.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  58
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_59.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  59
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_60.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  60
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_61.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  61
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_62.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  62
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_63.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  63
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_64.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  64
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_65.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  65
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_66.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  66
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_67.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  67
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_68.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  68
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift250ms_segments_69.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  69
# RAW/Validated/Combine Test
# Reading File :  C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV With Target Label 1
# SR 44100
# duration 182.50448979591837
# Segments 36
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_70.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  70
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_71.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  71
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_72.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  72
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_73.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  73
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_74.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  74
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_75.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  75
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_76.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  76
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_77.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  77
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_78.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  78
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_79.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  79
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_80.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  80
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_81.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  81
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_82.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  82
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_83.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  83
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_84.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  84
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_85.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  85
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_86.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  86
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_87.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  87
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_88.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  88
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_89.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  89
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_90.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  90
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_91.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  91
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_92.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  92
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_93.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  93
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_94.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  94
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_95.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  95
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_96.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  96
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_97.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  97
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_98.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  98
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_99.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  99
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_100.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  100
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_101.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  101
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_102.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  102
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_103.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  103
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift500ms_segments_104.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  104
# RAW/Validated/Combine Test
# Reading File :  C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV With Target Label 1
# SR 44100
# duration 182.50448979591837
# Segments 36
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift750ms_segments_105.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  105
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift750ms_segments_106.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  106
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift750ms_segments_107.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  107
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift750ms_segments_108.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  108
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift750ms_segments_109.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  109
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift750ms_segments_110.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  110
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift750ms_segments_111.WAV
# C:/Users/Another/CNN/RAW/Validated/Combine Test\Ambience\ZOOM0071_Tr4-Amb Talking.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  111
# RAW/Validated/Combine Test
# Extract Segment -  /ZOOM0071_Tr4-Amb Talking_Shift750ms_segments
.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel
# Data  7257
# RAW/Validated/Combine Test

# %%
print (i,"Data Extracted")
meaningful = dataset[0:i][:][:]
meaningfultarget = target[0:i]
AAA = list(meaningfultarget).count(0)
HHH = list(meaningfultarget).count(1)

CCC = list(meaningfultarget).count(2)
VVV = list(meaningfultarget).count(3)
Aper = int(AAA/i*100)
Hper = int(HHH/i*100)
Cper = int(CCC/i*100)
Vper = int(VVV/i*100)
print(AAA,"samples 0-Ambience ",Aper,"%")
print(HHH,"samples 1-Hatchet ",Hper,"%")
print(CCC,"samples 2-Chainsaw ",Cper,"%")
print(VVV,"samples 3-Vehicle ",Vper,"%")

print ("Final Data Extracted Shape",meaningful.shape)
print ("Final Target Extracted Shape",meaningfultarget.shape)

dist = "TT-" +str(i) +" A-" +str(Aper) + " H-"+str(Hper)+" C-"+str(Cper) +" V-"+str(Vper)
print(dist)
# Out:
# 7258 Data Extracted
# 1330 samples 0-Ambience  18 %
# 2622 samples 1-Hatchet  36 %
# 1311 samples 2-Chainsaw  18 %
# 1995 samples 3-Vehicle  27 %
# Final Data Extracted Shape (7258, 98, 40)
# Final Target Extracted Shape (7258,)
# TT-7258 A-18 H-36 C-18 V-27

# %%
sampleNameHere = "NewTrue_Unique-Out-of-Sample"
#sampleNameHere = "NewInSample"

# %% [markdown]
# # SAVE DATA AS NUMPY FILE

# %%
from datetime import datetime
dateTimeObj = datetime.now()
timestampStr = dateTimeObj.strftime(" %d-%b-%Y-%H%M")
 
print('Current Tdatasetimestamp : ', timestampStr)


filesavename = sampleNameHere+"Mel-Log-"+dist+"-"+str(meaningful.shape[1]) +"-"+str(meaningful.shape[2])+timestampStr+"H.npy"

filesavename
# Out:
# Current Tdatasetimestamp :   15-Dec-2019-1044
# 'NewTrue_Unique-Out-of-SampleMel-Log-TT-7258 A-18 H-36 C-18 V-27-98-40 15-Dec-2019-1044H.npy'

# %%
np.save("data"+filesavename, meaningful)
# save

np.save("target"+filesavename, meaningfultarget) # save

# %%
fs, signal = wav.read("TempDATA.WAV")
print(f)
print(fs,"kHz")
print("Channels",signal.shape)
if(np.array_equal(signal.shape, [220500, ])):
    print("1 Channel")
else:
    signal = signal[0:44100*5,0]
    print("2 Channels")
    
signal_preemphasized = speechpy.processing.preemphasis(signal, cof=0.98)
logenergy = speechpy.feature.lmfe(signal, sampling_frequency=fs, frame_length=para_fl, frame_stride=para_fl*0.5,
num_filters=40, fft_length=512, low_frequency=0, high_frequency=None)
# Out:
# C:/Users/Another/CNN/RAW/Validated/Combine Train\Machete\ZOOM0102_Tr4-Machete-100m.WAV
# 44100 kHz
# Channels (220500,)
# 1 Channel

# %%
logenergy[:][]
# Out:
# (98, 40)

# %%
dataset[1,:,:-1] = logenergy[:,:]

# %%
dataset.shape
# Out:
# (40000, 98, 41)

# %%
import numpy as np
N = 2
a = np.random.rand(N,N)
b = np.zeros((N,N+1))
b[:,:-1] = a

# %%
a
# Out:
# array([[0.00133972, 0.43270587],
#        [0.48049705, 0.89202945]])

# %%
b
# Out:
# array([[0.00133972, 0.43270587, 0.        ],
#        [0.48049705, 0.89202945, 0.        ]])
